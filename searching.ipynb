# %%
# Out:
# FileUpload(value=(), accept='audio/*', description='Upload')
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\Laptop24h\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipywidgets\widgets\widget.py:773, in Widget._handle_msg(self, msg)
#     771         if 'buffer_paths' in data:
#     772             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 773         self.set_state(state)
#     775 # Handle a state request.
#     776 elif method == 'request_state':
#
# File c:\Users\Laptop24h\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipywidgets\widgets\widget.py:650, in Widget.set_state(self, sync_data)
# ...
